# %% [markdown]
# <a href="https://colab.research.google.com/github/enjoyPG/pytorch_basic/blob/main/PyTorch_Image_Classification_Fine_Tuning_with%20Na.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * 학습 코드를 실행하기 전에 <b>[런타임]</b> - <b>[런타임 유형 변경]</b>에서 하드웨어 가속기를 <b>[GPU]</b>로 설정한다.
#
# ### <b>데이터 세트 다운로드</b>
#
# * 딥러닝 모델 학습 과정에서 필요한 데이터 세트를 불러온다.

# %%
# !git clone https://github.com/ndb7967/Materials
# %cd Materials
# Out:
# Cloning into 'Materials'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 77 (delta 1), reused 1 (delta 1), pack-reused 74
# Unpacking objects: 100% (77/77), 20.58 MiB | 13.88 MiB/s, done.
# /content/Materials/Materials

# %% [markdown]
# ### <b>라이브러리 불러오기(Load Libraries)</b>
#
# * 딥러닝 모델 학습 과정에서 필요한 라이브러리를 불러온다.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.datasets as datasets

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split

import matplotlib.pyplot as plt
import matplotlib.image as image
import numpy as np

# %% [markdown]
# ### <b>데이터 세트 불러오기(Load Dataset)</b>
#
# 1. <b>데이터 증진(data augmentation)</b>을 명시하여 초기화할 수 있다.
#   * 이미지를 불러올 때 어떤 방법(회전, 자르기, 뒤집기 등)을 사용할 것인지 명시한다.
# 2. 이후에 <b>DataLoader()</b>를 이용하여 실질적으로 데이터를 불러올 수 있다.
#   * 어떤 데이터를 사용할 것인지, 배치 크기(batch size), 데이터 셔플(shuffle) 여부 등을 명시한다.
#   * <b>next() 함수</b>를 이용하여 tensor 형태로 데이터를 배치 단위로 얻을 수 있다.
# * <b>Reference</b>: https://github.com/ndb7967/Materials/dataset

# %%
#보통 Resize -> 좌우반전(증진) -> 0~255를 0~1로 변경
transform_train = transforms.Compose([
    transforms.Resize((256, 256)), #이미지는 보통 256/256 사용
    transforms.RandomHorizontalFlip(), #데이터 증진
    transforms.ToTensor(),
    transforms.Normalize( # 0~255를 0~1로 변경
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

transform_val = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

transform_test = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

# %%
train_dataset = datasets.ImageFolder(
    root='dataset/fitness_classification_dataset/train_dataset',
    transform=transform_train
)
dataset_size = len(train_dataset)
train_size = int(dataset_size * 0.8)
val_size = dataset_size - train_size

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])
test_dataset = datasets.ImageFolder(
    root='dataset/fitness_classification_dataset/test_dataset',
    transform=transform_test
)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# ### <b>데이터 시각화(Data Visualization)</b>

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(input):
    # torch.Tensor => numpy
    input = input.numpy().transpose((1, 2, 0))
    # undo image normalization
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # display images
    plt.imshow(input)
    plt.show()

    
class_names = {
  0: "Man",
  1: "Woman",
  2: "Both",
}

# load a batch of train image
iterator = iter(train_dataloader)

# visualize a batch of train image
imgs, labels = next(iterator)
out = torchvision.utils.make_grid(imgs[:4])
imshow(out)
print([class_names[labels[i].item()] for i in range(4)])
# Out:
# ['Woman', 'Woman', 'Man', 'Man']

# %% [markdown]
# ### <b>딥러닝 모델 학습(Training)</b>
#
# * 사전 학습된(pre-trained) 모델(model)을 이용하여 가지고 있는 데이터 세트에 대한 학습이 가능하다.
#   * 네트워크의 마지막에 FC 레이어를 적용하여 클래스 개수를 일치시킨다.

# %%
learning_rate = 0.01
log_step = 20
n_classes = 3 #1000개로 되있는 것을 -> 3개의 클래스 수 변경

model = models.resnet50(pretrained=True) #전이학습 resnet50사용 //
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, n_classes) # transfer learning
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
import time


def train():
    start_time = time.time() 
    print(f'[Epoch: {epoch + 1} - Training]')
    model.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(train_dataloader): #batch사이즈 만큼 train데이터 불러옴
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        outputs = model(imgs)
        optimizer.zero_grad() #가중치 초기화(backward()호출때마다 가중치 누적되므로)
        _, preds = torch.max(outputs, 1) #예측 레이블 값 구하기(dimension=1을 기준으로 최대값 추출)
        loss = criterion(outputs, labels) #Criterion - loss 연산을 위한 함수로 여기서는 CrossEntropyLoss()사용
        
        loss.backward() #모델 구성하는 파라미터에 대한 기울기 계산
        optimizer.step() #경사하강법 시작, 가중치 조정
        
        total += labels.shape[0] #배치 레이블합 누계
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data) #모델이 예측한 레이블 값들과 실제 값이 같은(정확한 예측) 경우 구하기
        
        if i % log_step == log_step - 1:
            print(f'[Batch: {i + 1}] running train loss: {running_loss / total}, running train accuracy: {running_corrects / total}')

    print(f'train loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def validate():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Validation]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(val_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running val loss: {running_loss / total}, running val accuracy: {running_corrects / total}')

    print(f'val loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def test():
    start_time = time.time()
    print(f'[Test]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(test_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running test loss: {running_loss / total}, running test accuracy: {running_corrects / total}')

    print(f'test loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()

# %%
import time

def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 5:
        lr /= 10
    if epoch >= 10:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


num_epochs = 20
best_val_acc = 0
best_epoch = 0

history = []
accuracy = []
for epoch in range(num_epochs):
    adjust_learning_rate(optimizer, epoch)
    train_loss, train_acc = train()
    val_loss, val_acc = validate()
    history.append((train_loss, val_loss))
    accuracy.append((train_acc, val_acc))

    if val_acc > best_val_acc:
        print("[Info] best validation accuracy!")
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), f'best_checkpoint_epoch_{epoch + 1}.pth')

torch.save(model.state_dict(), f'last_checkpoint.pth')
# Out:
# [Epoch: 1 - Training]
# train loss: 0.1847844490638146, accuracy: 0.3076923191547394
# elapsed time: 0.422210693359375
# [Epoch: 1 - Validation]
# [Batch: 1] running val loss: 0.13626796007156372, running val accuracy: 0.75
# val loss: 0.13626796007156372, accuracy: 0.75
# elapsed time: 0.06337285041809082
# [Info] best validation accuracy!
# [Epoch: 2 - Training]
# train loss: 0.1439922681221595, accuracy: 0.46153849363327026
# elapsed time: 0.37456297874450684
# [Epoch: 2 - Validation]
# [Batch: 1] running val loss: 0.24874690175056458, running val accuracy: 0.25
# val loss: 0.24874690175056458, accuracy: 0.25
# elapsed time: 0.08047199249267578
# [Epoch: 3 - Training]
# train loss: 0.12594993527118975, accuracy: 0.692307710647583
# elapsed time: 0.49236059188842773
# [Epoch: 3 - Validation]
# [Batch: 1] running val loss: 0.16091564297676086, running val accuracy: 0.75
# val loss: 0.16091564297676086, accuracy: 0.75
# elapsed time: 0.09121513366699219
# [Epoch: 4 - Training]
# train loss: 0.029484407259867743, accuracy: 1.0
# elapsed time: 0.520249605178833
# [Epoch: 4 - Validation]
# [Batch: 1] running val loss: 0.28647106885910034, running val accuracy: 0.75
# val loss: 0.28647106885910034, accuracy: 0.75
# elapsed time: 0.0849599838256836
# [Epoch: 5 - Training]
# train loss: 0.014751823189166876, accuracy: 1.0
# elapsed time: 0.4420771598815918
# [Epoch: 5 - Validation]
# [Batch: 1] running val loss: 0.39617031812667847, running val accuracy: 0.75
# val loss: 0.39617031812667847, accuracy: 0.75
# elapsed time: 0.08079862594604492
# [Epoch: 6 - Training]
# train loss: 0.0023576196712943222, accuracy: 1.0
# elapsed time: 0.4899916648864746
# [Epoch: 6 - Validation]
# [Batch: 1] running val loss: 0.3452127277851105, running val accuracy: 0.75
# val loss: 0.3452127277851105, accuracy: 0.75
# elapsed time: 0.1014862060546875
# [Epoch: 7 - Training]
# train loss: 0.0017544886527153163, accuracy: 1.0
# elapsed time: 0.5507118701934814
# [Epoch: 7 - Validation]
# [Batch: 1] running val loss: 0.2976089119911194, running val accuracy: 0.75
# val loss: 0.2976089119911194, accuracy: 0.75
# elapsed time: 0.11122322082519531
# [Epoch: 8 - Training]
# train loss: 0.0026783039076970173, accuracy: 1.0
# elapsed time: 0.45305323600769043
# [Epoch: 8 - Validation]
# [Batch: 1] running val loss: 0.3152272701263428, running val accuracy: 0.75
# val loss: 0.3152272701263428, accuracy: 0.75
# elapsed time: 0.1052548885345459
# [Epoch: 9 - Training]
# train loss: 0.001600284559222368, accuracy: 1.0
# elapsed time: 0.6727399826049805
# [Epoch: 9 - Validation]
# [Batch: 1] running val loss: 0.3072715103626251, running val accuracy: 0.75
# val loss: 0.3072715103626251, accuracy: 0.75
# elapsed time: 0.13957667350769043
# [Epoch: 10 - Training]
# train loss: 0.007159656737572872, accuracy: 1.0
# elapsed time: 0.4678802490234375
# [Epoch: 10 - Validation]
# [Batch: 1] running val loss: 0.2342100590467453, running val accuracy: 0.75
# val loss: 0.2342100590467453, accuracy: 0.75
# elapsed time: 0.1403212547302246
# [Epoch: 11 - Training]
# train loss: 0.0015934293086712176, accuracy: 1.0
# elapsed time: 0.850339412689209
# [Epoch: 11 - Validation]
# [Batch: 1] running val loss: 0.258401095867157, running val accuracy: 0.75
# val loss: 0.258401095867157, accuracy: 0.75
# elapsed time: 0.27505993843078613
# [Epoch: 12 - Training]
# train loss: 0.0034103639996968783, accuracy: 1.0
# elapsed time: 1.2167437076568604
# [Epoch: 12 - Validation]
# [Batch: 1] running val loss: 0.24035446345806122, running val accuracy: 0.75
# val loss: 0.24035446345806122, accuracy: 0.75
# elapsed time: 0.2396996021270752
# [Epoch: 13 - Training]
# train loss: 0.001646684052852484, accuracy: 1.0
# elapsed time: 0.5217225551605225
# [Epoch: 13 - Validation]
# [Batch: 1] running val loss: 0.2400381863117218, running val accuracy: 0.75
# val loss: 0.2400381863117218, accuracy: 0.75
# elapsed time: 0.09254980087280273
# [Epoch: 14 - Training]
# train loss: 0.000934553905748404, accuracy: 1.0
# elapsed time: 0.5177443027496338
# [Epoch: 14 - Validation]
# [Batch: 1] running val loss: 0.2443685233592987, running val accuracy: 0.75
# val loss: 0.2443685233592987, accuracy: 0.75
# elapsed time: 0.11416792869567871
# [Epoch: 15 - Training]
# train loss: 0.007788201973128777, accuracy: 1.0
# elapsed time: 0.5369656085968018
# [Epoch: 15 - Validation]
# [Batch: 1] running val loss: 0.2212337851524353, running val accuracy: 0.75
# val loss: 0.2212337851524353, accuracy: 0.75
# elapsed time: 0.08701872825622559
# [Epoch: 16 - Training]
# train loss: 0.03969098160114999, accuracy: 0.9230769872665405
# elapsed time: 0.49715280532836914
# [Epoch: 16 - Validation]
# [Batch: 1] running val loss: 0.26635855436325073, running val accuracy: 0.75
# val loss: 0.26635855436325073, accuracy: 0.75
# elapsed time: 0.12243843078613281
# [Epoch: 17 - Training]
# train loss: 0.001305342365342837, accuracy: 1.0
# elapsed time: 0.5464365482330322
# [Epoch: 17 - Validation]
# [Batch: 1] running val loss: 0.2605128586292267, running val accuracy: 0.75
# val loss: 0.2605128586292267, accuracy: 0.75
# elapsed time: 0.14561963081359863
# [Epoch: 18 - Training]
# train loss: 0.01268728544863944, accuracy: 1.0
# elapsed time: 0.6020195484161377
# [Epoch: 18 - Validation]
# [Batch: 1] running val loss: 0.24051892757415771, running val accuracy: 0.75
# val loss: 0.24051892757415771, accuracy: 0.75
# elapsed time: 0.10259056091308594
# [Epoch: 19 - Training]
# train loss: 0.0009597997682598921, accuracy: 1.0
# elapsed time: 0.5092594623565674
# [Epoch: 19 - Validation]
# [Batch: 1] running val loss: 0.2629804015159607, running val accuracy: 0.75
# val loss: 0.2629804015159607, accuracy: 0.75
# elapsed time: 0.16391730308532715
# [Epoch: 20 - Training]
# train loss: 0.09982812773579589, accuracy: 0.7692307829856873
# elapsed time: 0.4936513900756836
# [Epoch: 20 - Validation]
# [Batch: 1] running val loss: 0.26957836747169495, running val accuracy: 0.75
# val loss: 0.26957836747169495, accuracy: 0.75
# elapsed time: 0.13893842697143555

# %% [markdown]
# ### <b>학습 결과 확인하기</b>
#
# * 학습 결과를 시각화하여 정상적으로 모델이 학습되었는지 확인한다.

# %%
plt.plot([x[0] for x in history], 'b', label='train')
plt.plot([x[1] for x in history], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot([x[0] for x in accuracy], 'b', label='train')
plt.plot([x[1] for x in accuracy], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
model = models.resnet50(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 3) # transfer learning
model = model.cuda()
model_path = 'last_checkpoint.pth'
model.load_state_dict(torch.load(model_path))

test_loss, test_accuracy = test()
print(f"Test loss: {test_loss:.8f}")
print(f"Test accuracy: {test_accuracy * 100.:.2f}%")
# Out:
# [Test]
# [Batch: 1] running test loss: 0.16117334365844727, running test accuracy: 0.75
# test loss: 0.41585981845855713, accuracy: 0.5
# elapsed time: 0.2571730613708496
# Test loss: 0.41585982
# Test accuracy: 50.00%
